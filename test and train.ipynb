# %%
import numpy as np 
import pandas as pd

# %%
orders = pd.read_csv('orders.csv')
orders
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
orders.loc[:,'order_number'].value_counts()
# Out:
# 1      206209
# 2      206209
# 3      206209
# 4      206209
# 5      182223
#         ...
# 96       1592
# 97       1525
# 98       1471
# 99       1421
# 100      1374
# Name: order_number, Length: 100, dtype: int64

# %%
prior=orders[orders['order_number'] > 1]
prior
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# 5         3367565        1             6          2                  7
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 1                          15.0
# 2                          21.0
# ...

# %%
prior['eval_set']='Prior'
prior
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# 5         3367565        1             6          2                  7
# ...           ...      ...           ...        ...                ...
# ...

# %%
order_products = pd.read_csv('order_products.csv')
order_products
# Out:
#           order_id  product_id  add_to_cart_order
# 0                2       33120                  1
# 1                2       28985                  2
# 2                2        9327                  3
# 3                2       45918                  4
# 4                2       30035                  5
# ...            ...         ...                ...
# 33819101   3421063       14233                  3
# 33819102   3421063       35548                  4
# 33819103   3421070       35951                  1
# 33819104   3421070       16953                  2
# 33819105   3421070        4724                  3
#
# [33819106 rows x 3 columns]

# %%
reorder = pd.merge(orders,order_products, on = "order_id",  how = "left")

# %%
reorder
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 33894101    272231   206209            14          6                 14
# 33894102    272231   206209            14          6                 14
# 33894103    272231   206209            14          6                 14
# 33894104    272231   206209            14          6                 14
# 33894105    272231   206209            14          6                 14
#
#           days_since_prior_order  product_id  add_to_cart_order
# ...

# %%
test = reorder[reorder['product_id'].isnull()]
test
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# 33892542   2728930   206202            23          2                 17
# 33892729    350108   206204             5          4                 14
# 33893066   1043943   206206            68          0                 20
# 33893290   2821651   206207            17          2                 13
# 33893968    803273   206208            50          5                 11
#
#           days_since_prior_order  product_id  add_to_cart_order
# ...

# %%
test['eval_set']='Test'
test
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# ...

# %%
test_new=test.iloc[:,[0,1,2,3,4,5,8]]
test_new
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# 33892542   2728930   206202            23          2                 17
# 33892729    350108   206204             5          4                 14
# 33893066   1043943   206206            68          0                 20
# 33893290   2821651   206207            17          2                 13
# 33893968    803273   206208            50          5                 11
#
#           days_since_prior_order eval_set
# 384                         11.0     Test
# ...

# %%
test_new.order_id.nunique()
# Out:
# 75000

# %%
frames=[test_new,prior]
result = pd.concat(frames)
result
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384       2774568        3            13          5                 15
# 403        329954        4             6          3                 12
# 464       1528013        6             4          3                 16
# 1086      1376945       11             8          6                 11
# 1161      1356845       12             6          1                 20
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order eval_set
# 384                        11.0     Test
# ...

# %%
result.loc[:,'eval_set'].value_counts()
# Out:
# Prior    3214874
# Test       75000
# Name: eval_set, dtype: int64

# %%
#result.order_id.nunique()

# %%
orders['eval_set']="Train"
orders
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order eval_set
# 0                           NaN    Train
# ...

# %%
orders.drop(result.index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-e235bfea4ecf> in <module>
# ----> 1 orders.drop(result.index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
a_new.loc[:,'eval_set'].value_counts()
# Out:
# Prior    3214874
# Name: eval_set, dtype: int64

# %%
#result2 = pd.concat([result, result1], axis=1)
#result2

# %%
#result1.fillna(value='Train')

# %%
train1 = orders[orders.order_number==1]
train1
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 11        2168274        2             1          2                 11
# 26        1374495        3             1          1                 14
# 39        3343014        4             1          6                 11
# 45        2717275        5             1          3                 12
# ...           ...      ...           ...        ...                ...
# 3420930    969311   206205             1          4                 12
# 3420934   3189322   206206             1          3                 18
# 3421002   2166133   206207             1          6                 19
# 3421019   2227043   206208             1          1                 15
# 3421069   3154581   206209             1          3                 11
#
#          days_since_prior_order eval_set
# 0                           NaN    Train
# ...

# %%
test_new
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 384        2774568        3            13          5                 15
# 403         329954        4             6          3                 12
# 464        1528013        6             4          3                 16
# 1086       1376945       11             8          6                 11
# 1161       1356845       12             6          1                 20
# ...            ...      ...           ...        ...                ...
# 33892542   2728930   206202            23          2                 17
# 33892729    350108   206204             5          4                 14
# 33893066   1043943   206206            68          0                 20
# 33893290   2821651   206207            17          2                 13
# 33893968    803273   206208            50          5                 11
#
#           days_since_prior_order eval_set
# 384                         11.0     Test
# ...
