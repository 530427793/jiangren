# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn.preprocessing as preprocessing
import re
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.tree import DecisionTreeClassifier

# %%
test = pd.read_csv('test.csv')
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train = pd.read_csv('train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
x=train['Age'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Titanic")
plt.ylabel('# of Age', fontsize=12)
plt.xlabel('Age',  fontsize=12)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Age')

# %%
x=train['Embarked'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Titanic")
plt.ylabel('# of Embarked', fontsize=12)
plt.xlabel('Embarked',  fontsize=12)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Embarked')

# %%
x=train['Fare'].value_counts()
x=x.sort_index()
#plot
plt.figure(figsize=(8,4))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Titanic")
plt.ylabel('# of Fare', fontsize=12)
plt.xlabel('Fare',  fontsize=12)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'Fare')

# %%
train.Survived.value_counts().plot(kind='bar')
plt.title(u"Survived (1 means survived)")
plt.ylabel(u"number")
# Out:
# Text(0, 0.5, 'number')

# %%
mean=train.groupby(['Pclass','Sex'])["Age"].aggregate("mean").reset_index()
mean
# Out:
#    Pclass     Sex        Age
# 0       1  female  34.611765
# 1       1    male  41.281386
# 2       2  female  28.722973
# 3       2    male  30.740707
# 4       3  female  21.750000
# 5       3    male  26.507589

# %%
not_null=train[train['Age'].notnull()]
not_null
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train[train['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
test[test['Age'].isnull()]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
age1={"Age":34.611765}
missing1 = train[(train.Pclass == 1) & (train.Sex == 'female')].fillna(value=age1)
missing1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 11                            Bonnell, Miss. Elizabeth  female  58.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  34.611765
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
# ..                                                 ...     ...        ...
# ...

# %%
age2={"Age":41.281386}
missing2 = train[(train.Pclass == 1) & (train.Sex == 'male')].fillna(value=age2)
missing2
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex        Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
age3={"Age":28.722973}
missing3 = train[(train.Pclass == 2) & (train.Sex == 'female')].fillna(value=age3)
missing3
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 41            42         0       2
# 43            44         1       2
# 53            54         1       2
# ..           ...       ...     ...
# 854          855         0       2
# 865          866         1       2
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
age4={"Age":30.740707}
missing4 = train[(train.Pclass == 2) & (train.Sex == 'male')].fillna(value=age4)
missing4
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex  \
# 17            18         1       2   Williams, Mr. Charles Eugene  male
# 20            21         0       2           Fynney, Mr. Joseph J  male
# 21            22         1       2          Beesley, Mr. Lawrence  male
# 33            34         0       2          Wheadon, Mr. Edward H  male
# 70            71         0       2     Jenkin, Mr. Stephen Curnow  male
# ..           ...       ...     ...                            ...   ...
# 848          849         0       2              Harper, Rev. John  male
# 861          862         0       2    Giles, Mr. Frederick Edward  male
# 864          865         0       2         Gill, Mr. John William  male
# 883          884         0       2  Banfield, Mr. Frederick James  male
# 886          887         0       2          Montvila, Rev. Juozas  male
#
#            Age  SibSp  Parch            Ticket  Fare Cabin Embarked
# ...

# %%
age5={"Age":21.750000}
missing5 = train[(train.Pclass == 3) & (train.Sex == 'female')].fillna(value=age5)
missing5
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 14            15         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 863          864         0       3
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.00      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.00      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.00      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.00      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.00      1
# ...

# %%
age6={"Age":26.507589}
missing6 = train[(train.Pclass == 3) & (train.Sex == 'male')].fillna(value=age6)
missing6
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 877          878         0       3            Petroff, Mr. Nedelio  male
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#            Age  SibSp  Parch           Ticket     Fare Cabin Embarked
# ...

# %%
age7={"Age":34.611765}
missing7 = test[(test.Pclass == 1) & (test.Sex == 'female')].fillna(value=age7)
age8={"Age":41.281386}
missing8 = test[(test.Pclass == 1) & (test.Sex == 'male')].fillna(value=age8)
age9={"Age":28.722973}
missing9 = test[(test.Pclass == 2) & (test.Sex == 'female')].fillna(value=age9)
missing9
age10={"Age":30.740707}
missing10 = test[(test.Pclass == 2) & (test.Sex == 'male')].fillna(value=age10)
missing10 
age11={"Age":21.750000}
missing11 = test[(test.Pclass == 3) & (test.Sex == 'female')].fillna(value=age11)
missing11
age12={"Age":26.507589}
missing12 = test[(test.Pclass == 3) & (test.Sex == 'male')].fillna(value=age12)
missing12
# Out:
#      PassengerId  Pclass                          Name   Sex        Age  \
# 0            892       3              Kelly, Mr. James  male  34.500000
# 3            895       3              Wirz, Mr. Albert  male  27.000000
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.000000
# 9            901       3       Davies, Mr. John Samuel  male  21.000000
# 10           902       3              Ilieff, Mr. Ylio  male  26.507589
# ..           ...     ...                           ...   ...        ...
# 399         1291       3      Conlon, Mr. Thomas Henry  male  31.000000
# 413         1305       3            Spector, Mr. Woolf  male  26.507589
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.500000
# 416         1308       3           Ware, Mr. Frederick  male  26.507589
# 417         1309       3      Peter, Master. Michael J  male  26.507589
#
#      SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %%
frames=[missing7,missing8,missing9,missing10,missing11,missing12]
test_new = pd.concat(frames)
test_new
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# ..           ...     ...                                                ...
# 399         1291       3                           Conlon, Mr. Thomas Henry
# 413         1305       3                                 Spector, Mr. Woolf
# 415         1307       3                       Saether, Mr. Simon Sivertsen
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
frames=[missing1,missing2,missing3,missing4,missing5,missing6]
train_new = pd.concat(frames)
train_new
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 877          878         0       3
# 878          879         0       3
# 881          882         0       3
# 884          885         0       3
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 11                            Bonnell, Miss. Elizabeth  female  58.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  34.611765
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
# ..                                                 ...     ...        ...
# ...

# %%
pick = ['Pclass', 'Age']

# %%
x_train = train_new[pick].values

# %%
y_train = train_new['Survived'].values

# %%
x_test = test_new[pick].values

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
          intercept_scaling=1, max_iter=100, multi_class='warn',
          n_jobs=None, penalty='l2', random_state=None, solver='warn',
          tol=0.0001, verbose=0, warm_start=False)
# Out:
# LogisticRegression(multi_class='warn', solver='warn')

# %%
y_predict = model.predict(x_train)

# %%
model.intercept_
# Out:
# array([3.53063477])

# %%
model.coef_
# Out:
# array([[-1.18668388, -0.04543031]])

# %%
(y_predict == y_train).mean()
# Out:
# 0.6958473625140292

# %%
y_esti = model.predict(x_test)

# %%
test_new['Survived'] = y_esti

# %%
submit = test_new[['PassengerId', 'Survived']]
